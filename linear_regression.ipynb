# %%
import pandas as pd
import  numpy as np
import  matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df= sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#how select to columns in one variable?
df_linear=df[['age', 'fare']]

# %%
sns.lmplot(x='age', y='fare',data=df_linear)

# %%
# X = df[['age']]
# y = df['fare']

# %%
# X.isnull().sum()*100/ len(X)

# %%
df_linear['age'].fillna(df_linear['age'].mean(), inplace=True)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_23248\254579991.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_linear['age'].fillna(df_linear['age'].mean(), inplace=True)
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_23248\254579991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# X.isnull().sum()*100/len(X)

# %%
# y.isnull().sum()*100/len(y)

# %%
df_linear.isnull().sum()
# Out:
# age     0
# fare    0
# dtype: int64

# %%
sns.lmplot(data=df_linear, x="age", y="fare")

# %%
sns.boxplot(y='age', data=df_linear)
# Out:
# <Axes: ylabel='age'>

# %%
# remove outliers from age column using IQR method?
Q1_age = df_linear['age'].quantile(0.25)
Q3_age = df_linear['age'].quantile(0.75)
IQR_age = Q3_age - Q1_age
lower_bound_age = Q1_age - 1.5 * IQR_age
upper_bound_age = Q3_age + 1.5 * IQR_age
df_linear = df_linear[((df_linear['age'] >= lower_bound_age ) & (df_linear['age'] <= upper_bound_age))]

# %%
sns.boxplot(data=df_linear, y="age")
# Out:
# <Axes: ylabel='age'>

# %%
# df_linear=df_linear[(df_linear['age'] < 50)]

# %%
# sns.boxplot(data=df_linear, y='age')

# %%
sns.boxplot(data=df_linear, y="fare")
# Out:
# <Axes: ylabel='fare'>

# %%
Q1_fare = df_linear['fare'].quantile(0.25)
Q3_fare = df_linear['fare'].quantile(0.75)
IQR_fare = Q3_fare - Q1_fare
lower_bound_fare = Q1_fare - 1.5 * IQR_fare
upper_bound_fare = Q3_fare + 1.5 * IQR_fare
df_linear = df_linear[((df_linear['fare'] >= lower_bound_fare ) & (df_linear['fare'] <= upper_bound_fare))]

# %%
sns.boxplot(data=df_linear, y="fare")
# Out:
# <Axes: ylabel='fare'>

# %%
# df_linear=df_linear[(df_linear['fare'] < 50)]

# %%
# sns.boxplot(data=df_linear, y="fare")

# %%
# sns.boxplot(data=df_linear, y="age")

# %%
X = df_linear[['age']]
y = df_linear['fare']

# %%
sns.lmplot(data=df_linear, x='age', y='fare')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#model ko  import kare
model= LinearRegression()
 #model ko train  kare
model.fit(X,y)
#model ko predict karna ha
#for loop on model.predict function from 1 to 100?
for i in range(1, 101):  # loop from 1 to 100
    predictions = model.predict([[i]])  # make a prediction for each iteration
    print(f"Prediction for {i}: {predictions}")
# model.predict([[5]])
# Out:
# Prediction for 1: [13.91161259]
# Prediction for 2: [14.03110502]
# Prediction for 3: [14.15059745]
# Prediction for 4: [14.27008988]
# Prediction for 5: [14.38958231]
# Prediction for 6: [14.50907474]
# Prediction for 7: [14.62856717]
# Prediction for 8: [14.7480596]
# Prediction for 9: [14.86755203]
# Prediction for 10: [14.98704446]
# Prediction for 11: [15.10653689]
# Prediction for 12: [15.22602932]
# Prediction for 13: [15.34552175]
# Prediction for 14: [15.46501418]
# Prediction for 15: [15.58450662]
# Prediction for 16: [15.70399905]
# Prediction for 17: [15.82349148]
# Prediction for 18: [15.94298391]
# Prediction for 19: [16.06247634]
# Prediction for 20: [16.18196877]
# Prediction for 21: [16.3014612]
# Prediction for 22: [16.42095363]
# Prediction for 23: [16.54044606]
# Prediction for 24: [16.65993849]
# Prediction for 25: [16.77943092]
# Prediction for 26: [16.89892335]
# Prediction for 27: [17.01841578]
# Prediction for 28: [17.13790821]
# ...

# %%
#Model Evaluation With Metrics
X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.8)
model1= LinearRegression()
model1.fit(X_train, y_train)
predictions2=model1.predict(X_test)

# %%
sns.scatterplot(x=y_test,y=predictions2)
# Out:
# <Axes: xlabel='fare'>

# %%
model1.score(X_test, y_test)
# Out:
# 0.0047212471219143515

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

MAE=mean_absolute_error(y_true=y_test,  y_pred=predictions2)
MSE=mean_squared_error(y_true=y_test,   y_pred=predictions2)
RMSE=mean_squared_error(y_true=y_test, y_pred=predictions2, squared=False)
R2=r2_score(y_true=y_test, y_pred=predictions2)

print("MAE:  ", MAE, "MSE: ",  MSE, "RMSE: ", RMSE, "R2: ", R2)
# Out:
# MAE:   10.661207410144415 MSE:  179.80271508771622 RMSE:  13.409053474713128 R2:  0.0047212471219143515
# C:\Users\PMLS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
